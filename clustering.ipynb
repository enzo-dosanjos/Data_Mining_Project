# %%
# load pandas to deal with the data
import pandas as pd
# Resampling
from sklearn.utils import resample
# Scaler
from sklearn.preprocessing import StandardScaler
# k-means
from sklearn.cluster import KMeans
# Hierarchical clustering
from sklearn.cluster import AgglomerativeClustering
# DBSCAN
from sklearn.cluster import DBSCAN
# plot
import matplotlib.pyplot as plt

# %%
data_cleaned = pd.read_csv("flickr_data2_cleaned.csv")

# Select only lat and long
df_clustering = data_cleaned[['lat', 'long']].dropna()
df_clustering.head()
# Out:
#          lat      long
# 0  45.754858  4.821710
# 1  45.753270  4.862953
# 2  45.760655  4.846564
# 3  45.784000  4.874072
# 4  45.784000  4.874072

# %%
# Scale the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df_clustering)

# Create scaled DataFrame
scaled_data_df = pd.DataFrame(
    data=scaled_data,
    columns=df_clustering.columns,
    index=df_clustering.index
)

scaled_data_df.head()
# Out:
#         lat      long
# 0 -0.472687 -0.563117
# 1 -0.527748  0.741057
# 2 -0.271688  0.222809
# 3  0.537754  1.092659
# 4  0.537754  1.092659

# %%
# number of clusters
k = 20  # à déterminer avec elbow method
# create a model
kmeans = KMeans(n_clusters=k, init='k-means++')
# fit scaled data
kmeans.fit(scaled_data_df)
# Out:
# KMeans(n_clusters=20)

# %%
# get cluster labels
labels = kmeans.labels_
print(f"k-means labels: {labels}")

# sum of squared distances
inertia = kmeans.inertia_
print(f"Sum of squared distances: {inertia}")

plt.figure(figsize=(8, 8))
plt.scatter(
    scaled_data_df['long'],
    scaled_data_df['lat'],
    c=labels,
    s=1,
)
plt.title(f"K-Means clustering (K={k})")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.show()
# Out:
# k-means labels: [ 0 18  3 ...  2 12  0]
# Sum of squared distances: 11984.715904834911

# %%
# Hierarchical clustering
# resample data to speed up computation
scaled_data_df = resample(
    scaled_data_df,
    n_samples=10000
)

hier = AgglomerativeClustering(
    n_clusters=k,
    distance_threshold=None,
    linkage='average',
    metric='euclidean',
    compute_full_tree=True,
    compute_distances=True,
)
hier.fit(scaled_data_df)
# Out:
# AgglomerativeClustering(compute_distances=True, compute_full_tree=True,
#                         linkage='average', n_clusters=20)

# %%
# get cluster labels
labels = hier.labels_
print(f"hierarchical clustering labels: {labels}")

plt.figure(figsize=(8, 8))
plt.scatter(
    scaled_data_df['long'],
    scaled_data_df['lat'],
    c=labels,
    s=1,
)
plt.title(f"Hierarchical clustering (K={k})")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.show()
# Out:
# hierarchical clustering labels: [6 1 1 ... 0 1 1]

# %%
# DBSCAN
dbscan = DBSCAN(
    eps=0.0005,
    min_samples=30,
)

dbscan.fit(df_clustering)
# Out:
# DBSCAN(eps=0.0005, min_samples=30)

# %%
labels = dbscan.labels_
print(f"DBSCAN labels: {labels}")

mask = labels != -1

plt.figure(figsize=(8, 8))
plt.scatter(
    df_clustering.loc[mask, 'long'],
    df_clustering.loc[mask, 'lat'],
    c=labels[mask],
    s=1,
)
plt.title(f"DBSCAN clustering")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.show()
# Out:
# DBSCAN labels: [  0  -1   1 ... 201   2   2]
